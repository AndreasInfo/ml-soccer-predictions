# %% [markdown]
# ### Load dependencies

# %%
import sys
print(f"Python version: {sys.version}\n")

print("Importiere Dependencies...")

import pandas as pd
print(f"... Pandas version: {pd.__version__}")
      
from datetime import datetime
print("... datetime: pre-installed")

import numpy as np
print("... Numpy: version {}".format(np.__version__))

import IPython
print("... IPython: version {}".format(IPython.__version__))

import sklearn
print("... scikit-learn: version {}".format(sklearn.__version__))

import math
print("... math: pre-installed")

import matplotlib.pyplot as plt
# %matplotlib inline

import itertools
print("... itertools: pre-installed")
# Out:
# Python version: 3.8.10 (default, Jun  2 2021, 10:49:15)
# [GCC 9.4.0]
#
# Importiere Dependencies...
# ... Pandas version: 1.2.2
# ... datetime: pre-installed
# ... Numpy: version 1.19.4
# ... IPython: version 7.20.0
# ... scikit-learn: version 1.0.1
# ... math: pre-installed
# ... itertools: pre-installed

# %%
OFFSET_COACH = 3
OFFSET_GAMES = 3

# %%
df_test = pd.read_csv('./src/tmp/df_test_ext.csv', index_col=0)
df_test.reset_index(inplace=True)
df_test.drop(columns=['index'], inplace=True)

df = df_test.copy(deep=True)

# %%
# df = df.loc[df['Season'].isin(['15/16', '16/17', '17/18', '18/19', '20/21'])]

# %%
#overview of all features
def info_me(df):
    df.info()

#describes numerical features
def describe_me(df):
    nr = len(df.describe().columns)
    cols = df.describe().columns
    rows = ['mean', 'std', 'min', '25%', '50%', '75%', 'max']

    fig, ax = plt.subplots(nrows=math.ceil(nr/3), ncols=3, figsize=(15, math.ceil(nr/3)*5))
    row_counter = 0
    col_counter = 0

    for col in cols:
        Y = []
        for row in rows:
            Y.append(df.describe()[col][row])

        color = 'tab:blue'
        ax[row_counter, col_counter].set_ylabel(col, fontsize=14)
        ax[row_counter, col_counter].plot(rows, Y, color=color)
        ax[row_counter, col_counter].tick_params(axis='y', labelsize=14)
        ax[row_counter, col_counter].tick_params(axis='x', rotation=60, labelsize=14)

        col_counter += 1
        if col_counter % 3 == 0:
            col_counter = 0
            row_counter += 1

    fig.tight_layout()

#correlation matrix of numerical features
def corr_me(df):
    size = len(df.corr().columns) * 0.7
    matrix = np.around(df.corr().values, decimals=2)
    labels = df.corr().columns

    fig, ax = plt.subplots(figsize=(size, size))
    im = ax.imshow(matrix)

    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))

    ax.set_xticklabels(labels, fontsize=14)
    ax.set_yticklabels(labels, fontsize=14)

    plt.setp(ax.get_xticklabels(), rotation=60, ha="right",
             rotation_mode="anchor")

    for i in range(len(labels)):
        for j in range(len(labels)):
            text = ax.text(j, i, matrix[i, j],
                           ha="center",
                           va="center",
                           color="w",
                           fontsize=14)

    fig.tight_layout()

# %%
# describe_me(df)

# %%
num_features = ['Home Offensive Shape',
                'Away Offensive Shape',
                'Home Aggresive Shape',
                'Away Aggresive Shape',
                'Home Offensive Shape Against',
                'Away Offensive Shape Against',
                'Home Aggresive Shape Against',
                'Away Aggresive Shape Against',
                'Home Rate',
                'Deuce Rate',
                'Away Rate',
                'Home Current Position On Table', # can also be treated as categorical feature
                'Away Current Position On Table', # can also be treated as categorical feature
                'Weighted Season'
               ]

cat_features = ['Home Team',
                'Away Team',
                'Matchday',
                'Weekday',
                'Season',
                'Home Coach',
                'Away Coach',
                f'Home Coach Substituted Within Last {OFFSET_COACH} Games',
                f'Away Coach Substituted Within Last {OFFSET_COACH} Games',
                'Home Promoted Last Year',
                'Away Promoted Last Year',
                'Kick Off Before 17:00',
               ]

# %%
from sklearn.model_selection import train_test_split

features = df.drop('Full Time Result', axis=1)
label = df['Full Time Result']

test_size = 306 - (3 * 9) #1 Season (306 games) - 3 Matchdays
X_train, X_test, y_train, y_test = train_test_split(features,
                                                    label,
                                                    test_size=test_size,
                                                    random_state=0,
                                                    shuffle=False)

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler()),
    ('binning', KBinsDiscretizer(encode='onehot-dense')),
#     ('poly', PolynomialFeatures())    
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, num_features),
        ('cat', categorical_transformer, cat_features)])

from sklearn.neighbors import KNeighborsClassifier

rfc = KNeighborsClassifier()

from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier

sfm = SelectFromModel(RandomForestClassifier(random_state=42)) 
rfecv = RFECV(RandomForestClassifier(n_estimators=10, random_state=42), step=10)

### MAGIC PART OF PIPELINE!!!
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                       ('selector',  sfm),
                       ('regressor', rfc)])

from sklearn.model_selection import GridSearchCV

param_grid = {
#     'preprocessor__num__poly__degree': [1, 2],
    'preprocessor__num__binning__strategy': ['uniform', 'quantile'],
    'preprocessor__num__binning__n_bins': [2, 5],
    'preprocessor__num__binning__encode': ['onehot', 'ordinal'],
#     'selector__threshold': ['0.5*median', '0.75*median', '1*median'],
    'regressor__n_neighbors': [2, 5, 10],
}

search = GridSearchCV(pipe,
                      param_grid,
                      cv=3,
                      n_jobs=-1,
                      refit=True,
                      verbose=3)

search.fit(X_train, y_train)

print()
print('GridSearchCV:')
print(f"Best score : {search.best_score_}")
print(f"Best params: {search.best_params_}")

print()
print("train_test_split() data:")
print(f"Train: {search.score(X_train, y_train)}")
print(f"Test : {search.score(X_test, y_test)}")

print()
print('Binning:')
print(search.best_estimator_.named_steps['preprocessor'].transformers_[0][1].named_steps['binning'].bin_edges_)

print()
prediction = search.predict(X_test)
(unique, counts) = np.unique(prediction, return_counts=True)
for u, c in zip(unique, counts):
    print(f"value: {u}, count: {c}")
    
from sklearn.metrics import classification_report
# Precision: Of all the predicted positives, how many were actually positive?
# Recall: Of all positives, how many did the model said it was positive?
# F1-score: The harmonic mean of precision and recall.
print()
print(classification_report(prediction, y_test))
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# /home/andreas/.local/lib/python3.8/site-packages/sklearn/preprocessing/_discretization.py:236: UserWarning: Bins whose width are too small (i.e., <= 1e-8) in feature 13 are removed. Consider decreasing the number of bins.
#   warnings.warn(
# GridSearchCV:
# Best score : 0.48234508650917435
# Best params: {'preprocessor__num__binning__encode': 'ordinal', 'preprocessor__num__binning__n_bins': 2, 'preprocessor__num__binning__strategy': 'quantile', 'regressor__n_neighbors': 10}
#
# train_test_split() data:
# Train: 0.5701125895598772
# Test : 0.5017921146953405
#
# Binning:
# [array([-2.55732928, -0.10270387,  4.04705429])
#  array([-2.78056771, -0.0898195 ,  3.98970198])
#  array([-3.12542458e+00, -5.11890256e-04,  3.44800578e+00])
#  array([-3.2698666 ,  0.00660538,  3.69429449])
#  array([-2.85484302, -0.01601399,  4.1746384 ])
#  array([-2.76610877, -0.02840234,  3.62416579])
#  array([-3.29333932, -0.02992606,  3.88271649])
#  array([-3.20068758, -0.03538998,  3.87764211])
#  array([-0.87763959, -0.25957726,  9.03894985])
#  array([-0.80512866, -0.38133792, 14.4513378 ])
#  array([-0.92156931, -0.3073998 , 13.25551028])
#  array([-1.66245626,  0.0740581 ,  1.61762643])
#  array([-1.61591062, -0.07421482,  1.66019296])
#  array([-0.35910682,  3.41344546])]
#
# value: A, count: 121
# value: D, count: 30
# value: H, count: 128
#
#               precision    recall  f1-score   support
#
#            A       0.67      0.49      0.56       121
#            D       0.16      0.40      0.23        30
#            H       0.59      0.54      0.56       128
#
#     accuracy                           0.50       279
#    macro avg       0.47      0.48      0.45       279
# weighted avg       0.58      0.50      0.53       279

# %%
def get_selected_features():     
    return 'TODOOOOO...'

print()
print("Selected features:")
print(get_selected_features())
# Out:
# Selected features:
# TODOOOOO...

# %%
from importlib import reload
import modules.make_simulations as msim
reload(msim)

# msim.simulate_betting_each_matchday(X_test, y_test, prediction)
msim.simulate_betting_each_game(X_test, y_test, prediction)
# msim.simulate_betting_each_game_on_favorite(X_test, y_test)
# Out:
# Bet per game: 10 Euro
#
# Augsburg - RB Leipzig (prediction=A result=A)
# Win     --> 5.3 Euro
# Balance --> 5.3 Euro
#
# Freiburg - Werder Bremen (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -4.7 Euro
#
# Hertha - Stuttgart (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -14.7 Euro
#
# Hoffenheim - Dortmund (prediction=A result=A)
# Win     --> 7.5 Euro
# Balance --> -7.2 Euro
#
# Mainz - Leverkusen (prediction=A result=A)
# Win     --> 5.7 Euro
# Balance --> -1.5 Euro
#
# Bielefeld - Bayern Munich (prediction=A result=A)
# Win     --> 1.6 Euro
# Balance --> 0.1 Euro
#
# M'gladbach - Wolfsburg (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -9.9 Euro
#
# FC Koln - Ein Frankfurt (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -19.9 Euro
#
# Schalke 04 - Union Berlin (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -29.9 Euro
#
# Stuttgart - FC Koln (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -39.9 Euro
#
# Bayern Munich - Ein Frankfurt (prediction=H result=H)
# Win     --> 1.6 Euro
# Balance --> -38.3 Euro
#
# Mainz - M'gladbach (prediction=A result=A)
# Win     --> 6.1 Euro
# Balance --> -32.2 Euro
#
# RB Leipzig - Hertha (prediction=H result=H)
# Win     --> 4.0 Euro
# Balance --> -28.2 Euro
#
# Union Berlin - Freiburg (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -38.2 Euro
#
# Dortmund - Schalke 04 (prediction=H result=H)
# Win     --> 1.6 Euro
# Balance --> -36.6 Euro
#
# Wolfsburg - Bielefeld (prediction=H result=H)
# Win     --> 6.5 Euro
# Balance --> -30.1 Euro
#
# Werder Bremen - Hoffenheim (prediction=D result=D)
# Win     --> 27.5 Euro
# Balance --> -2.6 Euro
#
# Leverkusen - Augsburg (prediction=H result=H)
# Win     --> 6.0 Euro
# Balance --> 3.4 Euro
#
# Schalke 04 - Stuttgart (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -6.6 Euro
#
# Augsburg - Mainz (prediction=H result=H)
# Win     --> 10.0 Euro
# Balance --> 3.4 Euro
#
# Bielefeld - Dortmund (prediction=A result=A)
# Win     --> 4.0 Euro
# Balance --> 7.4 Euro
#
# Ein Frankfurt - Werder Bremen (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -2.6 Euro
#
# FC Koln - Bayern Munich (prediction=A result=A)
# Win     --> 1.8 Euro
# Balance --> -0.8 Euro
#
# M'gladbach - RB Leipzig (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -10.8 Euro
#
# Freiburg - Leverkusen (prediction=A result=A)
# Win     --> 9.5 Euro
# Balance --> -1.3 Euro
#
# Hertha - Wolfsburg (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -11.3 Euro
#
# Hoffenheim - Union Berlin (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -21.3 Euro
#
# Werder Bremen - FC Koln (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -31.3 Euro
#
# Augsburg - Hertha (prediction=D result=A)
# Win     --> -10 Euro
# Balance --> -41.3 Euro
#
# Mainz - Schalke 04 (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -51.3 Euro
#
# RB Leipzig - Freiburg (prediction=H result=H)
# Win     --> 3.6 Euro
# Balance --> -47.7 Euro
#
# Stuttgart - Ein Frankfurt (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -57.7 Euro
#
# Union Berlin - Bielefeld (prediction=H result=H)
# Win     --> 8.3 Euro
# Balance --> -49.4 Euro
#
# Dortmund - Bayern Munich (prediction=D result=A)
# Win     --> -10 Euro
# Balance --> -59.4 Euro
#
# Wolfsburg - Hoffenheim (prediction=H result=H)
# Win     --> 11.0 Euro
# Balance --> -48.4 Euro
#
# Leverkusen - M'gladbach (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> -58.4 Euro
#
# Bayern Munich - Werder Bremen (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -68.4 Euro
#
# Bielefeld - Leverkusen (prediction=A result=A)
# Win     --> 5.0 Euro
# Balance --> -63.4 Euro
#
# Hoffenheim - Stuttgart (prediction=D result=D)
# Win     --> 27.5 Euro
# Balance --> -35.9 Euro
#
# M'gladbach - Augsburg (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -45.9 Euro
#
# Schalke 04 - Wolfsburg (prediction=A result=A)
# Win     --> 9.5 Euro
# Balance --> -36.4 Euro
#
# Ein Frankfurt - RB Leipzig (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -46.4 Euro
#
# Hertha - Dortmund (prediction=A result=A)
# Win     --> 6.5 Euro
# Balance --> -39.9 Euro
#
# Freiburg - Mainz (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -49.9 Euro
#
# FC Koln - Union Berlin (prediction=A result=A)
# Win     --> 16.0 Euro
# Balance --> -33.9 Euro
#
# Wolfsburg - Werder Bremen (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> -43.9 Euro
#
# Augsburg - Freiburg (prediction=D result=D)
# Win     --> 25.0 Euro
# Balance --> -18.9 Euro
#
# Dortmund - FC Koln (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -28.9 Euro
#
# RB Leipzig - Bielefeld (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> -38.9 Euro
#
# Stuttgart - Bayern Munich (prediction=A result=A)
# Win     --> 2.8 Euro
# Balance --> -36.1 Euro
#
# Union Berlin - Ein Frankfurt (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -46.1 Euro
#
# M'gladbach - Schalke 04 (prediction=H result=H)
# Win     --> 3.3 Euro
# Balance --> -42.8 Euro
#
# Leverkusen - Hertha (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -52.8 Euro
#
# Mainz - Hoffenheim (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -62.8 Euro
#
# Hertha - Union Berlin (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -72.8 Euro
#
# Bielefeld - Mainz (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -82.8 Euro
#
# Ein Frankfurt - Dortmund (prediction=D result=D)
# Win     --> 30.0 Euro
# Balance --> -52.8 Euro
#
# FC Koln - Wolfsburg (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -62.8 Euro
#
# Freiburg - M'gladbach (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -72.8 Euro
#
# Bayern Munich - RB Leipzig (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -82.8 Euro
#
# Werder Bremen - Stuttgart (prediction=A result=A)
# Win     --> 14.5 Euro
# Balance --> -68.3 Euro
#
# Schalke 04 - Leverkusen (prediction=A result=A)
# Win     --> 5.0 Euro
# Balance --> -63.3 Euro
#
# Hoffenheim - Augsburg (prediction=H result=H)
# Win     --> 8.3 Euro
# Balance --> -55.0 Euro
#
# Wolfsburg - Ein Frankfurt (prediction=H result=H)
# Win     --> 13.0 Euro
# Balance --> -42.0 Euro
#
# Dortmund - Stuttgart (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -52.0 Euro
#
# Freiburg - Bielefeld (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -62.0 Euro
#
# Mainz - FC Koln (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -72.0 Euro
#
# M'gladbach - Hertha (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -82.0 Euro
#
# RB Leipzig - Werder Bremen (prediction=H result=H)
# Win     --> 3.6 Euro
# Balance --> -78.4 Euro
#
# Union Berlin - Bayern Munich (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -88.4 Euro
#
# Augsburg - Schalke 04 (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -98.4 Euro
#
# Leverkusen - Hoffenheim (prediction=H result=H)
# Win     --> 7.5 Euro
# Balance --> -90.9 Euro
#
# Ein Frankfurt - M'gladbach (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -100.9 Euro
#
# Hertha - Mainz (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -110.9 Euro
#
# Stuttgart - Union Berlin (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -120.9 Euro
#
# Werder Bremen - Dortmund (prediction=A result=A)
# Win     --> 5.0 Euro
# Balance --> -115.9 Euro
#
# Schalke 04 - Freiburg (prediction=A result=A)
# Win     --> 13.0 Euro
# Balance --> -102.9 Euro
#
# Bayern Munich - Wolfsburg (prediction=H result=H)
# Win     --> 3.3 Euro
# Balance --> -99.6 Euro
#
# Bielefeld - Augsburg (prediction=A result=A)
# Win     --> 15.0 Euro
# Balance --> -84.6 Euro
#
# FC Koln - Leverkusen (prediction=A result=A)
# Win     --> 6.1 Euro
# Balance --> -78.5 Euro
#
# Hoffenheim - RB Leipzig (prediction=A result=A)
# Win     --> 6.0 Euro
# Balance --> -72.5 Euro
#
# Union Berlin - Dortmund (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -82.5 Euro
#
# Augsburg - Ein Frankfurt (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -92.5 Euro
#
# Mainz - Werder Bremen (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -102.5 Euro
#
# M'gladbach - Hoffenheim (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -112.5 Euro
#
# RB Leipzig - FC Koln (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -122.5 Euro
#
# Schalke 04 - Bielefeld (prediction=A result=A)
# Win     --> 24.0 Euro
# Balance --> -98.5 Euro
#
# Leverkusen - Bayern Munich (prediction=A result=A)
# Win     --> 8.3 Euro
# Balance --> -90.2 Euro
#
# Freiburg - Hertha (prediction=H result=H)
# Win     --> 15.0 Euro
# Balance --> -75.2 Euro
#
# Wolfsburg - Stuttgart (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> -85.2 Euro
#
# Bielefeld - M'gladbach (prediction=A result=A)
# Win     --> 5.3 Euro
# Balance --> -79.9 Euro
#
# Ein Frankfurt - Leverkusen (prediction=H result=H)
# Win     --> 22.0 Euro
# Balance --> -57.9 Euro
#
# FC Koln - Augsburg (prediction=A result=A)
# Win     --> 20.0 Euro
# Balance --> -37.9 Euro
#
# Hoffenheim - Freiburg (prediction=D result=A)
# Win     --> -10 Euro
# Balance --> -47.9 Euro
#
# Werder Bremen - Union Berlin (prediction=A result=A)
# Win     --> 13.7 Euro
# Balance --> -34.2 Euro
#
# Hertha - Schalke 04 (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> -44.2 Euro
#
# Stuttgart - RB Leipzig (prediction=A result=A)
# Win     --> 8.0 Euro
# Balance --> -36.2 Euro
#
# Dortmund - Wolfsburg (prediction=H result=H)
# Win     --> 5.5 Euro
# Balance --> -30.7 Euro
#
# Bayern Munich - Mainz (prediction=H result=H)
# Win     --> 1.2 Euro
# Balance --> -29.5 Euro
#
# M'gladbach - Bayern Munich (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -39.5 Euro
#
# Freiburg - FC Koln (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -49.5 Euro
#
# Leverkusen - Werder Bremen (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -59.5 Euro
#
# Mainz - Ein Frankfurt (prediction=A result=A)
# Win     --> 9.5 Euro
# Balance --> -50.0 Euro
#
# Schalke 04 - Hoffenheim (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -60.0 Euro
#
# Union Berlin - Wolfsburg (prediction=D result=D)
# Win     --> 23.0 Euro
# Balance --> -37.0 Euro
#
# RB Leipzig - Dortmund (prediction=A result=A)
# Win     --> 22.0 Euro
# Balance --> -15.0 Euro
#
# Augsburg - Stuttgart (prediction=D result=A)
# Win     --> -10 Euro
# Balance --> -25.0 Euro
#
# Bielefeld - Hertha (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -35.0 Euro
#
# Union Berlin - Leverkusen (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -45.0 Euro
#
# Dortmund - Mainz (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -55.0 Euro
#
# FC Koln - Hertha (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -65.0 Euro
#
# Hoffenheim - Bielefeld (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -75.0 Euro
#
# Werder Bremen - Augsburg (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> -85.0 Euro
#
# Wolfsburg - RB Leipzig (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -95.0 Euro
#
# Stuttgart - M'gladbach (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -105.0 Euro
#
# Bayern Munich - Freiburg (prediction=H result=H)
# Win     --> 2.2 Euro
# Balance --> -102.8 Euro
#
# Ein Frankfurt - Schalke 04 (prediction=H result=H)
# Win     --> 5.0 Euro
# Balance --> -97.8 Euro
#
# M'gladbach - Werder Bremen (prediction=H result=H)
# Win     --> 5.7 Euro
# Balance --> -92.1 Euro
#
# Hertha - Hoffenheim (prediction=A result=A)
# Win     --> 21.0 Euro
# Balance --> -71.1 Euro
#
# Leverkusen - Dortmund (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -81.1 Euro
#
# Mainz - Wolfsburg (prediction=A result=A)
# Win     --> 8.0 Euro
# Balance --> -73.1 Euro
#
# Schalke 04 - FC Koln (prediction=A result=A)
# Win     --> 17.5 Euro
# Balance --> -55.6 Euro
#
# Augsburg - Bayern Munich (prediction=A result=A)
# Win     --> 2.0 Euro
# Balance --> -53.6 Euro
#
# Bielefeld - Stuttgart (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -63.6 Euro
#
# Freiburg - Ein Frankfurt (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -73.6 Euro
#
# RB Leipzig - Union Berlin (prediction=H result=H)
# Win     --> 5.0 Euro
# Balance --> -68.6 Euro
#
# M'gladbach - Dortmund (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -78.6 Euro
#
# Augsburg - Union Berlin (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -88.6 Euro
#
# Bielefeld - Ein Frankfurt (prediction=A result=A)
# Win     --> 7.5 Euro
# Balance --> -81.1 Euro
#
# Freiburg - Stuttgart (prediction=H result=H)
# Win     --> 16.2 Euro
# Balance --> -64.9 Euro
#
# Leverkusen - Wolfsburg (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -74.9 Euro
#
# Mainz - RB Leipzig (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -84.9 Euro
#
# Hertha - Werder Bremen (prediction=A result=A)
# Win     --> 26.0 Euro
# Balance --> -58.9 Euro
#
# Schalke 04 - Bayern Munich (prediction=A result=A)
# Win     --> 1.4 Euro
# Balance --> -57.5 Euro
#
# Hoffenheim - FC Koln (prediction=H result=H)
# Win     --> 7.5 Euro
# Balance --> -50.0 Euro
#
# Stuttgart - Mainz (prediction=H result=H)
# Win     --> 6.1 Euro
# Balance --> -43.9 Euro
#
# Bayern Munich - Hoffenheim (prediction=H result=H)
# Win     --> 2.0 Euro
# Balance --> -41.9 Euro
#
# Dortmund - Augsburg (prediction=H result=H)
# Win     --> 2.5 Euro
# Balance --> -39.4 Euro
#
# Ein Frankfurt - Hertha (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> -49.4 Euro
#
# Union Berlin - M'gladbach (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -59.4 Euro
#
# Werder Bremen - Schalke 04 (prediction=D result=D)
# Win     --> 25.0 Euro
# Balance --> -34.4 Euro
#
# RB Leipzig - Leverkusen (prediction=H result=H)
# Win     --> 9.0 Euro
# Balance --> -25.4 Euro
#
# FC Koln - Bielefeld (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -35.4 Euro
#
# Wolfsburg - Freiburg (prediction=H result=H)
# Win     --> 8.5 Euro
# Balance --> -26.9 Euro
#
# Hertha - Bayern Munich (prediction=A result=A)
# Win     --> 3.6 Euro
# Balance --> -23.3 Euro
#
# Augsburg - Wolfsburg (prediction=A result=A)
# Win     --> 7.5 Euro
# Balance --> -15.8 Euro
#
# Freiburg - Dortmund (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -25.8 Euro
#
# Leverkusen - Stuttgart (prediction=H result=H)
# Win     --> 10.0 Euro
# Balance --> -15.8 Euro
#
# Mainz - Union Berlin (prediction=H result=H)
# Win     --> 23.0 Euro
# Balance --> 7.2 Euro
#
# Schalke 04 - RB Leipzig (prediction=A result=A)
# Win     --> 3.0 Euro
# Balance --> 10.2 Euro
#
# M'gladbach - FC Koln (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> 0.2 Euro
#
# Hoffenheim - Ein Frankfurt (prediction=A result=A)
# Win     --> 12.5 Euro
# Balance --> 12.7 Euro
#
# RB Leipzig - Augsburg (prediction=H result=H)
# Win     --> 2.2 Euro
# Balance --> 14.9 Euro
#
# Dortmund - Hoffenheim (prediction=D result=D)
# Win     --> 38.0 Euro
# Balance --> 52.9 Euro
#
# Leverkusen - Mainz (prediction=D result=D)
# Win     --> 40.0 Euro
# Balance --> 92.9 Euro
#
# Stuttgart - Hertha (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> 82.9 Euro
#
# Werder Bremen - Freiburg (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> 72.9 Euro
#
# Union Berlin - Schalke 04 (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> 62.9 Euro
#
# Ein Frankfurt - FC Koln (prediction=H result=H)
# Win     --> 4.5 Euro
# Balance --> 67.4 Euro
#
# Wolfsburg - M'gladbach (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> 57.4 Euro
#
# Bayern Munich - Bielefeld (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> 47.4 Euro
#
# Bielefeld - Wolfsburg (prediction=A result=A)
# Win     --> 6.5 Euro
# Balance --> 53.9 Euro
#
# Ein Frankfurt - Bayern Munich (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 43.9 Euro
#
# FC Koln - Stuttgart (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> 33.9 Euro
#
# Freiburg - Union Berlin (prediction=A result=A)
# Win     --> 21.0 Euro
# Balance --> 54.9 Euro
#
# M'gladbach - Mainz (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> 44.9 Euro
#
# Schalke 04 - Dortmund (prediction=A result=A)
# Win     --> 3.0 Euro
# Balance --> 47.9 Euro
#
# Augsburg - Leverkusen (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> 37.9 Euro
#
# Hertha - RB Leipzig (prediction=A result=A)
# Win     --> 6.5 Euro
# Balance --> 44.4 Euro
#
# Hoffenheim - Werder Bremen (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 34.4 Euro
#
# Werder Bremen - Ein Frankfurt (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 24.4 Euro
#
# Bayern Munich - FC Koln (prediction=H result=H)
# Win     --> 1.6 Euro
# Balance --> 26.0 Euro
#
# Dortmund - Bielefeld (prediction=H result=H)
# Win     --> 1.8 Euro
# Balance --> 27.8 Euro
#
# Stuttgart - Schalke 04 (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> 17.8 Euro
#
# Wolfsburg - Hertha (prediction=H result=H)
# Win     --> 7.0 Euro
# Balance --> 24.8 Euro
#
# RB Leipzig - M'gladbach (prediction=H result=H)
# Win     --> 6.0 Euro
# Balance --> 30.8 Euro
#
# Union Berlin - Hoffenheim (prediction=D result=D)
# Win     --> 25.0 Euro
# Balance --> 55.8 Euro
#
# Mainz - Augsburg (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> 45.8 Euro
#
# Leverkusen - Freiburg (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> 35.8 Euro
#
# Schalke 04 - Mainz (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> 25.8 Euro
#
# Ein Frankfurt - Stuttgart (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> 15.8 Euro
#
# Freiburg - RB Leipzig (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> 5.8 Euro
#
# Hertha - Augsburg (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -4.2 Euro
#
# Hoffenheim - Wolfsburg (prediction=H result=H)
# Win     --> 19.0 Euro
# Balance --> 14.8 Euro
#
# M'gladbach - Leverkusen (prediction=A result=A)
# Win     --> 16.0 Euro
# Balance --> 30.8 Euro
#
# Bayern Munich - Dortmund (prediction=H result=H)
# Win     --> 6.5 Euro
# Balance --> 37.3 Euro
#
# FC Koln - Werder Bremen (prediction=D result=D)
# Win     --> 22.5 Euro
# Balance --> 59.8 Euro
#
# Bielefeld - Union Berlin (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> 49.8 Euro
#
# Bielefeld - Werder Bremen (prediction=D result=A)
# Win     --> -10 Euro
# Balance --> 39.8 Euro
#
# Augsburg - M'gladbach (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 29.8 Euro
#
# Mainz - Freiburg (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 19.8 Euro
#
# Union Berlin - FC Koln (prediction=H result=H)
# Win     --> 9.0 Euro
# Balance --> 28.8 Euro
#
# Werder Bremen - Bayern Munich (prediction=A result=A)
# Win     --> 2.5 Euro
# Balance --> 31.3 Euro
#
# Wolfsburg - Schalke 04 (prediction=H result=H)
# Win     --> 3.3 Euro
# Balance --> 34.6 Euro
#
# Dortmund - Hertha (prediction=H result=H)
# Win     --> 5.0 Euro
# Balance --> 39.6 Euro
#
# Leverkusen - Bielefeld (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> 29.6 Euro
#
# RB Leipzig - Ein Frankfurt (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> 19.6 Euro
#
# Stuttgart - Hoffenheim (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 9.6 Euro
#
# Bielefeld - RB Leipzig (prediction=A result=A)
# Win     --> 3.3 Euro
# Balance --> 12.9 Euro
#
# Bayern Munich - Stuttgart (prediction=H result=H)
# Win     --> 2.0 Euro
# Balance --> 14.9 Euro
#
# Ein Frankfurt - Union Berlin (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> 4.9 Euro
#
# FC Koln - Dortmund (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -5.1 Euro
#
# Werder Bremen - Wolfsburg (prediction=A result=A)
# Win     --> 8.0 Euro
# Balance --> 2.9 Euro
#
# Schalke 04 - M'gladbach (prediction=A result=A)
# Win     --> 4.4 Euro
# Balance --> 7.3 Euro
#
# Hoffenheim - Mainz (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -2.7 Euro
#
# Hertha - Leverkusen (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -12.7 Euro
#
# Freiburg - Augsburg (prediction=H result=H)
# Win     --> 9.5 Euro
# Balance --> -3.2 Euro
#
# Augsburg - Hoffenheim (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> -13.2 Euro
#
# Dortmund - Ein Frankfurt (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -23.2 Euro
#
# Leverkusen - Schalke 04 (prediction=H result=H)
# Win     --> 2.2 Euro
# Balance --> -21.0 Euro
#
# Mainz - Bielefeld (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -31.0 Euro
#
# Wolfsburg - FC Koln (prediction=H result=H)
# Win     --> 5.0 Euro
# Balance --> -26.0 Euro
#
# RB Leipzig - Bayern Munich (prediction=A result=A)
# Win     --> 13.7 Euro
# Balance --> -12.3 Euro
#
# M'gladbach - Freiburg (prediction=H result=H)
# Win     --> 7.5 Euro
# Balance --> -4.8 Euro
#
# Stuttgart - Werder Bremen (prediction=H result=H)
# Win     --> 9.0 Euro
# Balance --> 4.2 Euro
#
# Union Berlin - Hertha (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -5.8 Euro
#
# Bielefeld - Freiburg (prediction=H result=H)
# Win     --> 18.7 Euro
# Balance --> 12.9 Euro
#
# Bayern Munich - Union Berlin (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> 2.9 Euro
#
# Ein Frankfurt - Wolfsburg (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -7.1 Euro
#
# Hertha - M'gladbach (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -17.1 Euro
#
# Werder Bremen - RB Leipzig (prediction=A result=A)
# Win     --> 4.0 Euro
# Balance --> -13.1 Euro
#
# Stuttgart - Dortmund (prediction=A result=A)
# Win     --> 8.3 Euro
# Balance --> -4.8 Euro
#
# Schalke 04 - Augsburg (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> -14.8 Euro
#
# FC Koln - Mainz (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -24.8 Euro
#
# Hoffenheim - Leverkusen (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -34.8 Euro
#
# RB Leipzig - Hoffenheim (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -44.8 Euro
#
# Augsburg - Bielefeld (prediction=D result=D)
# Win     --> 23.0 Euro
# Balance --> -21.8 Euro
#
# Freiburg - Schalke 04 (prediction=H result=H)
# Win     --> 6.5 Euro
# Balance --> -15.3 Euro
#
# M'gladbach - Ein Frankfurt (prediction=H result=H)
# Win     --> 15.0 Euro
# Balance --> -0.3 Euro
#
# Union Berlin - Stuttgart (prediction=H result=H)
# Win     --> 12.0 Euro
# Balance --> 11.7 Euro
#
# Wolfsburg - Bayern Munich (prediction=A result=A)
# Win     --> 9.0 Euro
# Balance --> 20.7 Euro
#
# Leverkusen - FC Koln (prediction=H result=H)
# Win     --> 6.1 Euro
# Balance --> 26.8 Euro
#
# Dortmund - Werder Bremen (prediction=H result=H)
# Win     --> 3.6 Euro
# Balance --> 30.4 Euro
#
# FC Koln - RB Leipzig (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 20.4 Euro
#
# Bayern Munich - Leverkusen (prediction=H result=H)
# Win     --> 4.0 Euro
# Balance --> 24.4 Euro
#
# Bielefeld - Schalke 04 (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 14.4 Euro
#
# Ein Frankfurt - Augsburg (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> 4.4 Euro
#
# Dortmund - Union Berlin (prediction=H result=H)
# Win     --> 5.0 Euro
# Balance --> 9.4 Euro
#
# Hoffenheim - M'gladbach (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -0.6 Euro
#
# Stuttgart - Wolfsburg (prediction=A result=A)
# Win     --> 10.0 Euro
# Balance --> 9.4 Euro
#
# Werder Bremen - Mainz (prediction=A result=A)
# Win     --> 13.7 Euro
# Balance --> 23.1 Euro
#
# Augsburg - FC Koln (prediction=A result=A)
# Win     --> 14.5 Euro
# Balance --> 37.6 Euro
#
# Freiburg - Hoffenheim (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> 27.6 Euro
#
# Mainz - Bayern Munich (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 17.6 Euro
#
# Union Berlin - Werder Bremen (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 7.6 Euro
#
# Wolfsburg - Dortmund (prediction=A result=A)
# Win     --> 11.5 Euro
# Balance --> 19.1 Euro
#
# Leverkusen - Ein Frankfurt (prediction=H result=H)
# Win     --> 11.5 Euro
# Balance --> 30.6 Euro
#
# RB Leipzig - Stuttgart (prediction=H result=H)
# Win     --> 3.6 Euro
# Balance --> 34.2 Euro
#
# M'gladbach - Bielefeld (prediction=H result=H)
# Win     --> 6.0 Euro
# Balance --> 40.2 Euro
#
# Mainz - Hertha (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> 30.2 Euro
#
# Hertha - Freiburg (prediction=H result=H)
# Win     --> 10.0 Euro
# Balance --> 40.2 Euro
#
# Stuttgart - Augsburg (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> 30.2 Euro
#
# Dortmund - RB Leipzig (prediction=D result=H)
# Win     --> -10 Euro
# Balance --> 20.2 Euro
#
# Hoffenheim - Schalke 04 (prediction=H result=H)
# Win     --> 2.0 Euro
# Balance --> 22.2 Euro
#
# Werder Bremen - Leverkusen (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> 12.2 Euro
#
# Wolfsburg - Union Berlin (prediction=H result=H)
# Win     --> 7.5 Euro
# Balance --> 19.7 Euro
#
# Bayern Munich - M'gladbach (prediction=H result=H)
# Win     --> 3.3 Euro
# Balance --> 23.0 Euro
#
# FC Koln - Freiburg (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> 13.0 Euro
#
# Ein Frankfurt - Mainz (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> 3.0 Euro
#
# Hertha - Bielefeld (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -7.0 Euro
#
# Schalke 04 - Hertha (prediction=A result=A)
# Win     --> 4.4 Euro
# Balance --> -2.6 Euro
#
# Augsburg - Werder Bremen (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -12.6 Euro
#
# Bielefeld - Hoffenheim (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -22.6 Euro
#
# Freiburg - Bayern Munich (prediction=A result=D)
# Win     --> -10 Euro
# Balance --> -32.6 Euro
#
# Hertha - FC Koln (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -42.6 Euro
#
# Leverkusen - Union Berlin (prediction=D result=D)
# Win     --> 28.0 Euro
# Balance --> -14.6 Euro
#
# M'gladbach - Stuttgart (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -24.6 Euro
#
# Schalke 04 - Ein Frankfurt (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -34.6 Euro
#
# Mainz - Dortmund (prediction=A result=A)
# Win     --> 4.4 Euro
# Balance --> -30.2 Euro
#
# RB Leipzig - Wolfsburg (prediction=H result=D)
# Win     --> -10 Euro
# Balance --> -40.2 Euro
#
# Bayern Munich - Augsburg (prediction=H result=H)
# Win     --> 1.2 Euro
# Balance --> -39.0 Euro
#
# Dortmund - Leverkusen (prediction=H result=H)
# Win     --> 5.0 Euro
# Balance --> -34.0 Euro
#
# Ein Frankfurt - Freiburg (prediction=H result=H)
# Win     --> 10.0 Euro
# Balance --> -24.0 Euro
#
# FC Koln - Schalke 04 (prediction=H result=H)
# Win     --> 3.3 Euro
# Balance --> -20.7 Euro
#
# Hoffenheim - Hertha (prediction=H result=H)
# Win     --> 9.0 Euro
# Balance --> -11.7 Euro
#
# Stuttgart - Bielefeld (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -21.7 Euro
#
# Union Berlin - RB Leipzig (prediction=A result=H)
# Win     --> -10 Euro
# Balance --> -31.7 Euro
#
# Werder Bremen - M'gladbach (prediction=A result=A)
# Win     --> 13.7 Euro
# Balance --> -18.0 Euro
#
# Wolfsburg - Mainz (prediction=H result=A)
# Win     --> -10 Euro
# Balance --> -28.0 Euro
#
# Hits       : 140/279 (0.5%) correctly guessed games
# Balance    : -28.0 Euro
# Min Balance: -122.5 Euro at index 85
# Max Balance: 92.9 Euro at index 154
# Investment : 2790 Euro
# Return     : -1.0%
